# %% [markdown]
# # Dict Creation

# %%
#empty dictionary
my_dict = {}

#dictionary with integer keys
my_dict = {1: 'abc', 2: 'xyz'}
print(my_dict)

#dictionary with mixed keys
my_dict = {'name': 'binal', 1: ['abc', 'xyz']}
print(my_dict)

#create empty dictionary using dict()
my_dict = dict()

my_dict = dict([(1, 'abc'),(2, 'xyz')])   #create a dict with list of tuples
print(my_dict)
# Out:
# {1: 'abc', 2: 'xyz'}
# {'name': 'binal', 1: ['abc', 'xyz']}
# {1: 'abc', 2: 'xyz'}

# %% [markdown]
# # Dict Access

# %%
my_dict = {'name' : 'binal', 'age': '30', 'address': 'ahmedabad'}

#get name
print(my_dict['name'])
# Out:
# binal

# %%
#if key is not present it gives KeyError
print(my_dict['degree'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14625/380485075.py in <cell line: 0>()
#       1 #if key is not present it gives KeyError
# ----> 2 print(my_dict['degree'])
#
# KeyError: 'degree'

# %%
#another way of accessing key
print(my_dict.get('address'))
# Out:
# ahmedabad

# %%
#if key is not present it will give None using get method
print(my_dict.get('degree','key does"nt exists'))
# Out:
# key does"nt exists

# %% [markdown]
# # Dict Add or Modify  Elements

# %%
my_dict = {'name' : 'binal', 'age': '30', 'address': 'ahmedabad'}

 #update name
my_dict['name'] = 'mahit'
print(my_dict)
# Out:
# {'name': 'mahit', 'age': '30', 'address': 'ahmedabad'}

# %%
#add new key

my_dict['degree'] = 'msc it'

print(my_dict)
# Out:
# {'name': 'mahit', 'age': '30', 'address': 'ahmedabad', 'degree': 'msc it'}

# %% [markdown]
# # Dict Delete or Remove Element

# %%
#create a dictionary
my_dict = {'name' : 'binal', 'age': '30', 'address': 'ahmedabad'}

#remove a particular item
print(my_dict.pop('age'))
print(my_dict)
# Out:
# 30
# {'name': 'binal', 'address': 'ahmedabad'}

# %%
my_dict = {'name' : 'binal', 'age': '30', 'address': 'ahmedabad'}

#remove an arbitarty key
my_dict.popitem()

print(my_dict)
# Out:
# {'name': 'binal', 'age': '30'}

# %%
squares = {2: 4, 3: 9, 4: 16, 5: 25}
#delete particular key
del squares[3]
print(squares)
# Out:
# {2: 4, 4: 16, 5: 25}

# %%
#remove all items
squares.clear()
print(squares)
# Out:
# {}

# %% [markdown]
# # Dictionary Methods

# %%
squares = {2: 4, 3: 9, 4: 16, 5: 25}
my_dict =squares.copy()

print(my_dict)
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25}

# %%
id(squares), id(my_dict)
# Out:
# (132233554435520, 132233557939072)

# %%
#fromkeys[seq[, v]] -> Return a new dictionary with keys from seq and value equal to v (defaults to None).
subject = {}.fromkeys(['maths', 'english', 'hindi'], [0, 1, 2])
print(subject)
# Out:
# {'maths': [0, 1, 2], 'english': [0, 1, 2], 'hindi': [0, 1, 2]}

# %%
subjects = {2:4, 3:9, 4:16, 5:25}

print(subjects.items()) #return a new view of the dictionary items (key, value)
# Out:
# dict_items([(2, 4), (3, 9), (4, 16), (5, 25)])

# %%
subjects = {2:4, 3:9, 4:16, 5:25}
print(subjects.keys()) #return a new view of the dictionary keys
# Out:
# dict_keys([2, 3, 4, 5])

# %%
subjects = {2:4, 3:9, 4:16, 5:25}
print(subjects.values()) #return a new view of the dictionary values
# Out:
# dict_values([4, 9, 16, 25])

# %%
#get list of all available methods and attributes of dictionary
d = {}
print(dir(d))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %% [markdown]
# # Dict Comprehension

# %%
d = {'a': 1, 'b': 2, 'c': 3}
for pair in d.items():
    print(pair)
# Out:
# ('a', 1)
# ('b', 2)
# ('c', 3)

# %%
#Creating a new dictionary with only pairs where the value is larger than 2
d = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
new_dict = {k:v for k, v in d.items() if v > 2}
print(new_dict)
# Out:
# {'c': 3, 'd': 4}

# %%
#We can also perform operations on the key value pairs
d = {'a':1,'b':2,'c':3,'d':4,'e':5}

d = {k + 'c':v * 2 for k, v in d.items() if v > 2}

print(d)
# Out:
# {'cc': 6, 'dc': 8, 'ec': 10}
