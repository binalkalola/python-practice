# %% [markdown]
# # Set Creation

# %%
#set of integers
s = {1, 2, 3}
print(s)

#print type of s
print(type(s))
# Out:
# {1, 2, 3}
# <class 'set'>

# %%
#set doesn't allow duplicates. They store only one instance.
s = {1, 2, 3, 1, 4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
#we can make set from a list

s = set([1, 2, 3])
print(s)
# Out:
# {1, 2, 3}

# %%
#initialize a set  with set() method
s = set()

print(type(s))
# Out:
# <class 'set'>

# %% [markdown]
# # Add element to a Set

# %%
#we can add single element using add() method and
#add multiple elements using update() method

s = {1, 2}

# Sets are unordered and do not support indexing.
# Attempting to access a set element using an index raises a TypeError.

print(s[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1419/1256880572.py in <cell line: 0>()
#       7 # Attempting to access a set element using an index raises a TypeError.
#       8
# ----> 9 print(s[1])
#
# TypeError: 'set' object is not subscriptable

# %%
#add elemts
s.add(3)
print(s)

# %%
#add multiple elements
s.update([5, 6, 1])
print(s)

# %%
#add list and set

s.update([7, 8, 9], {10, 2, 3})
print(s)

# %% [markdown]
# # Remove elements from a Set

# %%
#A particular item can be removed from set using methods,
#discard() and remove().

s = {1, 2, 3, 4, 5, 6}
print(s)

s.discard(4)
print(s)

# %%
#remove an element
s.remove(2)
print(s)
# Out:
# {1}

# %%
# The remove() method raises a KeyError if the specified element is not present.
s.remove(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1419/106092973.py in <cell line: 0>()
#       1 # The remove() method raises a KeyError if the specified element is not present.
# ----> 2 s.remove(7)
#
# KeyError: 7

# %%
#discard an element not present in a set s
s.discard(7)
print(s)

# %%
#we can remove item using pop() method
s = {1, 2, 3, 5, 4}
s.pop()  #remove random element

print(s)

# %%
s.pop()
print(s)

# %%
s = {1, 5, 2, 3, 6}

s.clear()  #remove all items in set using clear() method

print(s)

# %% [markdown]
# # Python Set Operations

# %%
set1 = {1, 2, 3, 4}
set2 = {4, 5, 6}

#union of 2 sets using | operator

print(set1 | set2)

# %%
#another way of getting union of 2 sets
print(set1.union(set2))

# %%
#intersection of 2 sets using & operator

print(set1 & set2)

# %%
#use intersection function

print(set1.intersection(set2))

# %%
#set Difference: set of elements that are only in set1 but not in set2
print(set1 - set2)

# %%
#use differnce function

print(set1.difference(set2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1419/4061264749.py in <cell line: 0>()
#       1 #use differnce function
#       2
# ----> 3 print(set1.difference(set2))
#
# NameError: name 'set1' is not defined

# %%
"""symmetric difference: set of elements in both set1 and set2
#except those that are common in both."""

#use ^ operator

print(set1^set2)

# %%
#use symmetric_difference function

print(set1.symmetric_difference(set2))

# %%
#find issubset()

x = {'a', 'b', 'c', 'd', 'e'}
y ={'c','d','e'}

print("set 'x' is subset of 'y'?", x.issubset(y)) #check x is subset of y

print("set 'y' is subset of 'x?", y.issubset(x)) #check y is subset of x

# %% [markdown]
# # Frozen Sets

# %%
set1 = frozenset([1, 2, 3, 4, 5])
set2 = frozenset([3, 4, 5, 6])

#try to add element into set1 gives an error
set1.add(5)

# %%
print(set1[1])  # frozen set doesn't support indexing

# %%
print(set1 | set2)

# %%
#intersection of two sets

print(set1 & set2)

#or

print(set1.intersection(set2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1419/669742008.py in <cell line: 0>()
#       1 #intersection of two sets
#       2
# ----> 3 print(set1 & set2)
#       4
#       5 #or
#
# NameError: name 'set1' is not defined

# %%
#symmetric difference

print(set1 ^ set2)

print(set1.symmetric_difference(set2))
